# %% [markdown]
# # Introduction:
# In This Notebook we will utilize sklearn's TFIDF Vectorize feature to convert text data from wine description column to numeric variables that we can use to find similarities between given wine and others in the gathered dataset.

# %%
## Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

pd.options.mode.chained_assignment = None 

## Import TFIDF libraries
import random
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Read CSV file
wine_df = pd.read_csv('C:/Users/ADMIN/Desktop/DS Projects/My Vivino/My Vivino Project/new_wine.csv', index_col = 0)

# %%
# Keep only the wine data that have wine description inplace since we are building recommendation system based on Description 
wine_df = wine_df[wine_df['wine description'].notna()]

# Reset Index after deleting rows that does not have wine description 
wine_df = wine_df.reset_index()
# Drop 'index' column that appears after resetting index 
wine_df = wine_df.drop(columns = ['index'])

wine_df
# Out:
#                        wine name        winery  wine year  wine rating  \
# 0             Cabernet Sauvignon   Carta Vieja     2019.0          3.4
# 1                         Merlot   Carta Vieja     2019.0          3.4
# 2             Cabernet Sauvignon  Three Wishes        NaN          3.1
# 3             Cabernet Sauvignon    Crane Lake     2016.0          3.4
# 4                     Pinot Noir    Crane Lake     2016.0          3.4
# ...                          ...           ...        ...          ...
# 12791        Bin 27 Reserve Port       Fonseca        NaN          3.8
# 12792  Terra Bella Reserve Porto       Fonseca        NaN          3.8
# 12793            Malamado Malbec      Zuccardi        NaN          3.7
# 12794            Malamado Malbec      Zuccardi     2012.0          3.7
# 12795            Malamado Malbec      Zuccardi     2013.0          3.6
#
#        wine price  wine type        wine region   wine country  \
# 0            4.99        Red  Loncomilla Valley          Chile
# 1            4.99        Red  Loncomilla Valley          Chile
# 2            4.99        Red         California  United States
# 3            4.99        Red         California  United States
# 4            4.99        Red         California  United States
# ...           ...        ...                ...            ...
# 12791       13.00  Fortified              Porto       Portugal
# 12792       22.99  Fortified              Porto       Portugal
# 12793       25.99  Fortified            Mendoza      Argentina
# 12794       19.99  Fortified            Mendoza      Argentina
# 12795       22.99  Fortified            Mendoza      Argentina
#
#         grape information  wine acidity  wine intensity  wine sweetness  \
# 0      Cabernet Sauvignon      3.043747        3.781781        1.772746
# 1                  Merlot      2.020424        3.482722        1.949938
# 2      Cabernet Sauvignon      3.206160        4.545627        1.962006
# 3      Cabernet Sauvignon      3.014199        4.738935        1.743180
# 4              Pinot Noir      3.405433        2.832203        1.500866
# ...                   ...           ...             ...             ...
# 12791    Touriga Nacional      3.023872        4.767150        4.843369
# 12792    Touriga Nacional      2.979524        4.617777        4.679206
# 12793              Malbec      2.502118        3.910410        4.366497
# 12794              Malbec      2.502118        3.910410        4.366497
# 12795              Malbec      2.502118        3.910410        4.366497
#
#        wine tannin                                   wine description  \
# 0         3.164342  Cabernet Sauvignon is the most widely grown gr...
# 1         2.366192  Merlot is a staple of the wine producing regio...
# 2         3.569953  Known as the king of red wine grapes, Cabernet...
# 3         3.540428  Known as the king of red wine grapes, Cabernet...
# 4         2.147871  Pinot Noir has the well deserved reputation of...
# ...            ...                                                ...
# 12791          NaN  Produced exclusively in the Douro Valley of No...
# 12792          NaN  Produced exclusively in the Douro Valley of No...
# 12793     2.316115  Extremely popular, Argentinian Malbec is an in...
# 12794     2.316115  Extremely popular, Argentinian Malbec is an in...
# 12795     2.316115  Extremely popular, Argentinian Malbec is an in...
#
#        wine price log
# 0            1.607436
# 1            1.607436
# 2            1.607436
# 3            1.607436
# 4            1.607436
# ...               ...
# 12791        2.564949
# 12792        3.135059
# 12793        3.257712
# 12794        2.995232
# 12795        3.135059
#
# [12796 rows x 15 columns]

# %% [markdown]
# I have picked wines below to test my recommendation system. It is not required to list 5 wines, you are free to input different wines based on your preferences

# %%
list_of_wines  = ['Barrancas Vineyards Alta Syrah',
                  'Egri Bikavér Bulls Blood',
                  'Valle Escondido Merlot',
                  'Cuvée Tradition Brut Rosé',
                  'Rot']
wines_index = []

# For loop appends the indexes of the picked wines
for wine_name in list_of_wines:
    wines_index.append(wine_df[wine_df['wine name'] == wine_name].index[0])

# Then I create a new column called "user's choice" and equate everything to zero apart from 5 wines selected earlier
wine_df ["user's choice"] = 0

for index in wines_index:
    wine_df.loc[index, "user's choice"] = 1
wine_df[wine_df["user's choice"] == 1]


wine_df["user's choice"] = wine_df["user's choice"].apply(lambda x: np.nan if x ==0 else x)
# wine_df.iloc[random_numbers_list]
wine_df["user's choice"].value_counts()
# Out:
# 1.0    5
# Name: user's choice, dtype: int64

# %%
def tfidf_recommendation(df):
    
    """
    Takes in a data frame with wine descriptions, passes the descriptions into a TFIDF function, determines
    the similarity of a given observation/description to the rest of the inputs using cosine similarity, 
    and return a data frame with the top similarity scores for each of our wines.
    """
    
    # Extract wine description column
    
    all_descriptions = df[['wine description']]
    
    # Initialize a TFIDF Vectorizer model to work with the text data
    
    tf = TfidfVectorizer(analyzer='word',
                     min_df=0,
                     stop_words='english')

    # Use the initiated TFIDF model to transform the data in descriptions
    
    tfidf_matrix = tf.fit_transform(all_descriptions['wine description'])
    
    # Compute the cosine similarities between the items in the newly transformed TFIDF matrix
    cosine_similarities = cosine_similarity(tfidf_matrix,tfidf_matrix)
    
    # Reset the index of the data frame to be able to iterate through the index with our smaller data frame
    
    user_indeces = df.reset_index()
    user_indeces = user_indeces[user_indeces["user's choice"] == 1]

    # Initialize a dictionary to store the results
    
    results = {} 

    # Iterate through the observation of Arielle's choices
    
    for idx, row in user_indeces.iterrows():

        similar_indices = cosine_similarities[idx].argsort()[:-5:-1] # Extract the top 5 wines for each observation that user likes
        similar_items = [(cosine_similarities[idx][i], df.reset_index()['index'][i]) for i in similar_indices] # Find the TFIDF score of that item
        results[row['index']] = similar_items[1:] # Append all results after the first (which will be itself) to the dictionary
        
    tfidf_recs = pd.DataFrame()

    # Iterate through the dictionary of results to add the recommended values to a data frame
    
    for k, v in results.items():
    
        for i in v:
        
            tfidf_recs = tfidf_recs.append(df[df.index.isin([i[1]])])
            
    tfidf_scores = []

    # Iterate through the data frame of recommended wines to find their TFIDF scores and add that to the data frame
    
    for i in tfidf_recs.index:
    
        for k, v in results.items():
        
            for ele in v:
            
                if i == ele[1]:
            
                    tfidf_scores.append(ele[0])
    
    tfidf_recs['tfidf_score'] = tfidf_scores[0:len(tfidf_recs)]
    
    return tfidf_recs

# %% [markdown]
# ### Description Based Recommendation:

# %%
new_tfidf_recs = tfidf_recommendation(wine_df)
new_tfidf_recs
# Out:
#                                       wine name           winery  wine year  \
# 4777                                    Cuvée 7           Sauska     2016.0
# 1721                    Dolomite Cabernet Franc            Raats     2016.0
# 2884                    Dolomite Cabernet Franc            Raats     2017.0
# 303                               Estate Merlot  Humberto Canale     2016.0
# 2944                           Merlot (Classic)           Montes     2018.0
# 3207   Cuvée Alexandre Merlot (Apalta Vineyard)       Lapostolle     2015.0
# 3613                                        Rot          Schwarz     2013.0
# 2522                                      Pitti        Pittnauer     2018.0
# 2788                     Valpolicella Superiore          Musella     2017.0
# 1261                                      Syrah     Smoking Loon     2017.0
# 6647                                      Syrah       Kongsgaard     2014.0
# 5406               Colson Canyon Vineyard Syrah          Tensley     2015.0
# 11809                 Cuvée Tradition Brut Rosé            Miolo     2012.0
# 11331                          Sparkling Blanco          Sandara        NaN
# 11396                          Sparkling Muscat           Botani     2013.0
#
#        wine rating  wine price  wine type           wine region  \
# 4777           4.1   57.990000        Red               Villány
# 1721           3.7   27.990000        Red          Stellenbosch
# 2884           3.8   18.040833        Red          Stellenbosch
# 303            3.4    9.990000        Red             Rio Negro
# 2944           3.5   18.990000        Red      Colchagua Valley
# 3207           3.9   18.990833        Red      Colchagua Valley
# 3613           4.1   64.990000        Red            Burgenland
# 2522           3.8   17.000000        Red            Burgenland
# 2788           3.5   17.990000        Red          Valpolicella
# 1261           3.8   13.990000        Red            California
# 6647           4.2  199.990000        Red           Napa Valley
# 5406           4.1   69.000000        Red  Santa Barbara County
# 11809          3.4   15.750000  Sparkling     Vale dos Vinhedos
# 11331          3.7   10.990000  Sparkling              Valencia
# 11396          3.7   19.990000  Sparkling                Málaga
#
#         wine country   grape information  wine acidity  wine intensity  \
# 4777         Hungary  Cabernet Sauvignon           NaN        3.948318
# 1721    South Africa      Cabernet Franc      3.383157        3.543047
# 2884    South Africa      Cabernet Franc      3.383157        3.543047
# 303        Argentina              Merlot      2.399199        3.590889
# 2944           Chile              Merlot      1.801770        3.934795
# 3207           Chile              Merlot      1.926770        3.967185
# 3613         Austria            Zweigelt      3.816559        3.282410
# 2522         Austria            Zweigelt      3.980691        3.023554
# 2788           Italy             Corvina      3.485892        2.967525
# 1261   United States        Shiraz/Syrah      3.065899        4.351349
# 6647   United States        Shiraz/Syrah           NaN        4.264243
# 5406   United States        Shiraz/Syrah           NaN        4.446639
# 11809         Brazil          Chardonnay      3.590650        2.973936
# 11331          Spain            Xarel-lo           NaN             NaN
# 11396          Spain            Xarel-lo      3.095167        2.943528
#
#        wine sweetness  wine tannin  \
# 4777         1.615174     3.935267
# 1721         1.459468     3.583633
# 2884         1.459468     3.583633
# 303          1.947797     2.493179
# 2944         2.032921     1.884926
# 3207         2.028907     2.073914
# 3613         1.787342     3.235215
# 2522         1.404613     3.307066
# 2788         1.961507     2.543161
# 1261         1.475967     3.377084
# 6647         2.105262     3.687479
# 5406         1.924829     3.585088
# 11809             NaN          NaN
# 11331             NaN          NaN
# 11396             NaN          NaN
#
#                                         wine description  wine price log  \
# 4777   Bordeaux blends from Hungary are jammy and ric...        4.060271
# 1721   Cabernet Franc in South Africa can produce a v...        3.331847
# 2884   Cabernet Franc in South Africa can produce a v...        2.892638
# 303    Merlot is a relatively new grape in Argentina ...        2.301585
# 2944   Merlot is a staple of the wine producing regio...        2.943913
# 3207   Merlot is a staple of the wine producing regio...        2.943956
# 3613   The fruit-forward and spicy Zweigelt, with fla...        4.174233
# 2522   The fruit-forward and spicy Zweigelt, with fla...        2.833213
# 2788   The red wines of Valpolicella have a lot to of...        2.889816
# 1261   Californian Syrah certainly isn't a wine for t...        2.638343
# 6647   Californian Syrah certainly isn't a wine for t...        5.298267
# 5406   Californian Syrah certainly isn't a wine for t...        4.234107
# 11809  Sparkling wines from Brazil take on many diffe...        2.756840
# 11331  While the majority of Cava is dry, it ranges i...        2.396986
# 11396  While the majority of Cava is dry, it ranges i...        2.995232
#
#        user's choice  tfidf_score
# 4777             NaN     1.000000
# 1721             NaN     0.124832
# 2884             NaN     0.124832
# 303              NaN     1.000000
# 2944             NaN     0.245839
# 3207             NaN     0.245839
# 3613             1.0     1.000000
# 2522             NaN     1.000000
# 2788             NaN     0.109529
# 1261             NaN     0.296080
# 6647             NaN     0.296080
# 5406             NaN     0.296080
# 11809            1.0     1.000000
# 11331            NaN     0.206948
# 11396            NaN     0.206948

# %% [markdown]
# We can see that recommended does a good job by suggesting wines of same type, from similar regions and price tags (you can see initially selected wines from few cells showed below).
#
# Comparing to the previous wine rating based recommendation system, this is some improvement in quality of suggestions. Some wines have tfidf score of 1.0 which means that wine description is exactly same as the one that was initially selectied.
#
# It is because majority of the wines that have same winery locations/grape information have the same description as well. This can be resolved by gathering/scraping high-quality data from the web. I will do that after submitting the following project :)

# %% [markdown]
# ### Initially selected wines:

# %%
wine_df[wine_df["user's choice"] == 1]
# Out:
#                             wine name        winery  wine year  wine rating  \
# 539          Egri Bikavér Bulls Blood       Egervin     2017.0          3.5
# 1260           Valle Escondido Merlot   Gouguenheim     2017.0          3.8
# 3613                              Rot       Schwarz     2013.0          4.1
# 5051   Barrancas Vineyards Alta Syrah  Pascual Toso     2016.0          4.2
# 11809       Cuvée Tradition Brut Rosé         Miolo     2012.0          3.4
#
#        wine price  wine type        wine region wine country  \
# 539         10.99        Red               Eger      Hungary
# 1260        13.99        Red            Mendoza    Argentina
# 3613        64.99        Red         Burgenland      Austria
# 5051        60.99        Red            Mendoza    Argentina
# 11809       15.75  Sparkling  Vale dos Vinhedos       Brazil
#
#         grape information  wine acidity  wine intensity  wine sweetness  \
# 539    Cabernet Sauvignon      4.482264        3.895974        1.249128
# 1260               Merlot      2.011888        3.913674        1.631071
# 3613             Zweigelt      3.816559        3.282410        1.787342
# 5051         Shiraz/Syrah           NaN        4.372199        1.906853
# 11809          Chardonnay      3.590650        2.973936             NaN
#
#        wine tannin                                   wine description  \
# 539       4.287904  Bordeaux blends from Hungary are jammy and ric...
# 1260      2.213240  Merlot is a relatively new grape in Argentina ...
# 3613      3.235215  The fruit-forward and spicy Zweigelt, with fla...
# 5051      3.527991  Syrah is a big, thick-skinned grape that origi...
# 11809          NaN  Sparkling wines from Brazil take on many diffe...
#
#        wine price log  user's choice
# 539          2.396986            1.0
# 1260         2.638343            1.0
# 3613         4.174233            1.0
# 5051         4.110710            1.0
# 11809        2.756840            1.0

# %% [markdown]
# # What happens if we choose Wines Randomly?

# %% [markdown]
# Let's try to generate randomly 5 wines from the dataset. Again, you can generate more or less than 5 wines.

# %%
# This Cell creates list of randomly generated numbers
random_numbers_list = []

for i in range (5):
    random_number = random.randrange(0, len(wine_df))
    random_numbers_list.append(random_number)
random_numbers_list
# Out:
# [937, 7961, 12562, 12133, 3560]

# %%
# DataFrame of Wines that generated from random index
wine_df.iloc[random_numbers_list]
# Out:
#                                 wine name                       winery  \
# 937                            Pinot Noir                Chasing Lions
# 7961   Diamond Collection Sauvignon Blanc  Francis Ford Coppola Winery
# 12562                         Bandol Rosé    Domaine de la Tour du Bon
# 12133  Palmes d'Or Vintage Brut Champagne           Nicolas Feuillatte
# 3560                           Pinot Noir                   Wild Ridge
#
#        wine year  wine rating  wine price  wine type   wine region  \
# 937       2017.0          4.0       12.99        Red    California
# 7961      2015.0          3.7       15.99      White    California
# 12562     2019.0          3.9       23.21       Rose        Bandol
# 12133     1999.0          4.4      139.99  Sparkling     Champagne
# 3560      2014.0          4.0       42.99        Red  Sonoma Coast
#
#         wine country grape information  wine acidity  wine intensity  \
# 937    United States        Pinot Noir      3.207955        2.944879
# 7961   United States   Sauvignon Blanc      3.996501        3.060451
# 12562         France      Shiraz/Syrah      3.895482        2.661442
# 12133         France        Chardonnay      4.455622        4.023271
# 3560   United States        Pinot Noir      3.511116        3.302398
#
#        wine sweetness  wine tannin  \
# 937          1.896073     2.101255
# 7961         1.384674          NaN
# 12562        1.484822          NaN
# 12133             NaN          NaN
# 3560         1.473219     2.181562
#
#                                         wine description  wine price log  \
# 937    Pinot Noir has the well deserved reputation of...        2.564180
# 7961   California is known primarily for its Cabernet...        2.771964
# 12562  No summer afternoon is complete without a litt...        3.144583
# 12133  While there are many sparkling wine regions ar...        4.941571
# 3560   Pinot Noir has the well deserved reputation of...        3.760968
#
#        user's choice
# 937              NaN
# 7961             NaN
# 12562            NaN
# 12133            NaN
# 3560             NaN

# %%
# Same process as previously described
wine_df ["user's choice"] = 0

for index in random_numbers_list:
    wine_df.loc[index, "user's choice"] = 1
wine_df[wine_df["user's choice"] == 1]
# Out:
#                                 wine name                       winery  \
# 937                            Pinot Noir                Chasing Lions
# 3560                           Pinot Noir                   Wild Ridge
# 7961   Diamond Collection Sauvignon Blanc  Francis Ford Coppola Winery
# 12133  Palmes d'Or Vintage Brut Champagne           Nicolas Feuillatte
# 12562                         Bandol Rosé    Domaine de la Tour du Bon
#
#        wine year  wine rating  wine price  wine type   wine region  \
# 937       2017.0          4.0       12.99        Red    California
# 3560      2014.0          4.0       42.99        Red  Sonoma Coast
# 7961      2015.0          3.7       15.99      White    California
# 12133     1999.0          4.4      139.99  Sparkling     Champagne
# 12562     2019.0          3.9       23.21       Rose        Bandol
#
#         wine country grape information  wine acidity  wine intensity  \
# 937    United States        Pinot Noir      3.207955        2.944879
# 3560   United States        Pinot Noir      3.511116        3.302398
# 7961   United States   Sauvignon Blanc      3.996501        3.060451
# 12133         France        Chardonnay      4.455622        4.023271
# 12562         France      Shiraz/Syrah      3.895482        2.661442
#
#        wine sweetness  wine tannin  \
# 937          1.896073     2.101255
# 3560         1.473219     2.181562
# 7961         1.384674          NaN
# 12133             NaN          NaN
# 12562        1.484822          NaN
#
#                                         wine description  wine price log  \
# 937    Pinot Noir has the well deserved reputation of...        2.564180
# 3560   Pinot Noir has the well deserved reputation of...        3.760968
# 7961   California is known primarily for its Cabernet...        2.771964
# 12133  While there are many sparkling wine regions ar...        4.941571
# 12562  No summer afternoon is complete without a litt...        3.144583
#
#        user's choice
# 937                1
# 3560               1
# 7961               1
# 12133              1
# 12562              1

# %%
# Same process as previously described

wine_df["user's choice"] = wine_df["user's choice"].apply(lambda x: np.nan if x ==0 else x)

wine_df["user's choice"].value_counts()

wine_df.iloc[random_numbers_list]
# Out:
#                                 wine name                       winery  \
# 937                            Pinot Noir                Chasing Lions
# 7961   Diamond Collection Sauvignon Blanc  Francis Ford Coppola Winery
# 12562                         Bandol Rosé    Domaine de la Tour du Bon
# 12133  Palmes d'Or Vintage Brut Champagne           Nicolas Feuillatte
# 3560                           Pinot Noir                   Wild Ridge
#
#        wine year  wine rating  wine price  wine type   wine region  \
# 937       2017.0          4.0       12.99        Red    California
# 7961      2015.0          3.7       15.99      White    California
# 12562     2019.0          3.9       23.21       Rose        Bandol
# 12133     1999.0          4.4      139.99  Sparkling     Champagne
# 3560      2014.0          4.0       42.99        Red  Sonoma Coast
#
#         wine country grape information  wine acidity  wine intensity  \
# 937    United States        Pinot Noir      3.207955        2.944879
# 7961   United States   Sauvignon Blanc      3.996501        3.060451
# 12562         France      Shiraz/Syrah      3.895482        2.661442
# 12133         France        Chardonnay      4.455622        4.023271
# 3560   United States        Pinot Noir      3.511116        3.302398
#
#        wine sweetness  wine tannin  \
# 937          1.896073     2.101255
# 7961         1.384674          NaN
# 12562        1.484822          NaN
# 12133             NaN          NaN
# 3560         1.473219     2.181562
#
#                                         wine description  wine price log  \
# 937    Pinot Noir has the well deserved reputation of...        2.564180
# 7961   California is known primarily for its Cabernet...        2.771964
# 12562  No summer afternoon is complete without a litt...        3.144583
# 12133  While there are many sparkling wine regions ar...        4.941571
# 3560   Pinot Noir has the well deserved reputation of...        3.760968
#
#        user's choice
# 937              1.0
# 7961             1.0
# 12562            1.0
# 12133            1.0
# 3560             1.0

# %%
alternative_tfidf_recs = tfidf_recommendation(wine_df)

alternative_tfidf_recs
# Out:
#                                 wine name             winery  wine year  \
# 1589                           Pinot Noir           Rickshaw     2019.0
# 6119      Russian River Valley Pinot Noir       Kosta Browne     2014.0
# 1577                   Pinot Noir Clone 4            Cambria     2016.0
# 1589                           Pinot Noir           Rickshaw     2019.0
# 6119      Russian River Valley Pinot Noir       Kosta Browne     2014.0
# 1577                   Pinot Noir Clone 4            Cambria     2016.0
# 7895                      Sauvignon Blanc             Girard     2017.0
# 7597                      Sauvignon Blanc             Thrive     2017.0
# 8993                      Sauvignon Blanc  Long Meadow Ranch     2018.0
# 12027       Cuvée Alain Thienot Champagne            Thienot     2007.0
# 11701  Le Clos Champagne Grand Cru 'Bouzy       Andre Clouet     2008.0
# 11703    Belle Epoque Rosé Brut Champagne      Perrier-Jouët     2004.0
# 12443                     Rock Angel Rosé  Château d'Esclans     2016.0
# 12429                      Esprit Gassier            Gassier     2018.0
# 12430                   Côtes de Provence  Fleurs de Prairie     2018.0
#
#        wine rating  wine price  wine type                  wine region  \
# 1589           3.6   14.990000        Red                Sonoma County
# 6119           4.6  115.000000        Red         Russian River Valley
# 1577           3.8   14.990000        Red           Santa Maria Valley
# 1589           3.6   14.990000        Red                Sonoma County
# 6119           4.6  115.000000        Red         Russian River Valley
# 1577           3.8   14.990000        Red           Santa Maria Valley
# 7895           3.6   15.979167      White                  Napa Valley
# 7597           3.6   13.990000      White                   California
# 8993           4.0   26.000000      White                   Rutherford
# 12027          4.2   90.000000  Sparkling                    Champagne
# 11701          4.3  267.990000  Sparkling  Champagne Grand Cru 'Bouzy'
# 11703          4.6  279.000000  Sparkling                    Champagne
# 12443          4.1   83.990000       Rose            Côtes de Provence
# 12429          3.8   14.000000       Rose            Côtes de Provence
# 12430          4.0   16.090000       Rose            Côtes de Provence
#
#         wine country grape information  wine acidity  wine intensity  \
# 1589   United States        Pinot Noir      3.520112        2.865938
# 6119   United States        Pinot Noir           NaN        3.143511
# 1577   United States        Pinot Noir      3.484797        2.930700
# 1589   United States        Pinot Noir      3.520112        2.865938
# 6119   United States        Pinot Noir           NaN        3.143511
# 1577   United States        Pinot Noir      3.484797        2.930700
# 7895   United States   Sauvignon Blanc      4.077648        3.014764
# 7597   United States   Sauvignon Blanc      4.012355        2.934420
# 8993   United States   Sauvignon Blanc      4.029200        3.013259
# 12027         France        Chardonnay      4.619952        4.102551
# 11701         France        Chardonnay      4.611603        4.117764
# 11703         France        Chardonnay      4.587965        3.809982
# 12443         France      Shiraz/Syrah      3.924219        2.625712
# 12429         France      Shiraz/Syrah      3.938587        2.416922
# 12430         France      Shiraz/Syrah      3.977356        2.478112
#
#        wine sweetness  wine tannin  \
# 1589         1.462285     2.053480
# 6119         1.687798     2.058886
# 1577         1.590514     2.137889
# 1589         1.462285     2.053480
# 6119         1.687798     2.058886
# 1577         1.590514     2.137889
# 7895         1.310916          NaN
# 7597         1.116860          NaN
# 8993         1.416183          NaN
# 12027             NaN          NaN
# 11701             NaN          NaN
# 11703             NaN          NaN
# 12443        1.382278          NaN
# 12429        1.363166          NaN
# 12430        1.378758          NaN
#
#                                         wine description  wine price log  \
# 1589   Pinot Noir has the well deserved reputation of...        2.707383
# 6119   Pinot Noir has the well deserved reputation of...        4.744932
# 1577   Pinot Noir has the well deserved reputation of...        2.707383
# 1589   Pinot Noir has the well deserved reputation of...        2.707383
# 6119   Pinot Noir has the well deserved reputation of...        4.744932
# 1577   Pinot Noir has the well deserved reputation of...        2.707383
# 7895   California is known primarily for its Cabernet...        2.771286
# 7597   California is known primarily for its Cabernet...        2.638343
# 8993   California is known primarily for its Cabernet...        3.258097
# 12027  While there are many sparkling wine regions ar...        4.499810
# 11701  While there are many sparkling wine regions ar...        5.590950
# 11703  While there are many sparkling wine regions ar...        5.631212
# 12443  No summer afternoon is complete without a litt...        4.430698
# 12429  No summer afternoon is complete without a litt...        2.639057
# 12430  No summer afternoon is complete without a litt...        2.778198
#
#        user's choice  tfidf_score
# 1589             NaN          1.0
# 6119             NaN          1.0
# 1577             NaN          1.0
# 1589             NaN          1.0
# 6119             NaN          1.0
# 1577             NaN          1.0
# 7895             NaN          1.0
# 7597             NaN          1.0
# 8993             NaN          1.0
# 12027            NaN          1.0
# 11701            NaN          1.0
# 11703            NaN          1.0
# 12443            NaN          1.0
# 12429            NaN          1.0
# 12430            NaN          1.0

# %% [markdown]
# Here We can see that all reccommended wines have tfidf score of 1.0. This is because Vivino API provided same description for majority of the wines that have same winery location and/or grape information. However, we could see that the recommendation system is effective from the previous example.

# %% [markdown]
# # Conclusion
# We can see that the Description Based Recommendation System recommended 15 wines based on our input of 5 wines. I have given two
# approaches on how to use description based recommendations:
#
# 1) Inputting the wines you have previously consumed and liked. Then, the system will look for wines that have similar wine descriptions and give some recommendations based on the tfidf value
#
# 2) Randomly Generate some wines to see how the recommendation system works. Since majority of the wines have the same description and number of unique wine descriptions is limited, the tfidf value will be 1.0 which means it will search for the wines that have exactly same description. It could be solved by scraping for high-quality data. The quality of data is essential in building recommendation systems. Building of collaborative filtering model is also depends on the data quality gathered
